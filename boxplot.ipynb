# %% [markdown]
# ### 二分类结果箱线图

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 从Excel文件加载数据
df = pd.read_excel(r'C:\Users\ynn\Desktop\result\binary.xlsx')

# 提取每个指标的数据列
acc = df['acc']
f1 = df['f1']
precision = df['precision']
recall = df['recall']

# 设置颜色
box_colors = ['#0077B6', '#00D4B8', '#90E0EF','#CAF0F8']

# 绘制箱线图
plt.figure(figsize=(10, 6))

# 使用patch_artist=True来启用填充色
boxes = plt.boxplot([acc, f1, precision, recall], 
                    labels=['Accuracy', 'F1', 'Precision', 'Recall'],
                    patch_artist=True)

# 为每个箱子设置颜色
for box, color in zip(boxes['boxes'], box_colors):
    box.set_facecolor(color)

# 设置其他绘图属性
plt.title('Performance Metrics Comparison')
plt.ylabel('Score')
plt.grid(False)
# 去掉右侧和上边的框线
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)
# plt.ylim(0)
plt.show()

# %% [markdown]
# ### 三分类结果箱线图

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 从Excel文件加载数据
df = pd.read_excel(r'C:\Users\ynn\Desktop\result\multiclass.xlsx')

# 提取每个指标的数据列
acc = df['acc']
f1 = df['f1']
precision = df['precision']
recall = df['recall']

# 设置颜色
box_colors = ['#0077B6', '#00D4B8', '#90E0EF','#CAF0F8']

# 绘制箱线图
plt.figure(figsize=(10, 6))

# 使用patch_artist=True来启用填充色
boxes = plt.boxplot([acc, f1, precision, recall], 
                    labels=['Accuracy', 'F1', 'Precision', 'Recall'],
                    patch_artist=True)

# 为每个箱子设置颜色
for box, color in zip(boxes['boxes'], box_colors):
    box.set_facecolor(color)

# 设置其他绘图属性
plt.title('Performance Metrics Comparison')
plt.ylabel('Score')
plt.grid(False)
# 去掉右侧和上边的框线
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)
# plt.ylim(0)
plt.show()

# %% [markdown]
# ### 外部验证箱线图

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 从Excel文件加载数据
df = pd.read_excel(r'C:\Users\ynn\Desktop\result\yanzheng2.xlsx')

# 提取每个指标的数据列
acc = df['acc']
f1 = df['f1']
precision = df['precision']
recall = df['recall']

# 设置颜色
box_colors = ['#0077B6', '#00D4B8', '#90E0EF','#CAF0F8']

# 绘制箱线图
plt.figure(figsize=(10, 6))

# 使用patch_artist=True来启用填充色
boxes = plt.boxplot([acc, f1, precision, recall], 
                    labels=['Accuracy', 'F1', 'Precision', 'Recall'],
                    patch_artist=True)

# 为每个箱子设置颜色
for box, color in zip(boxes['boxes'], box_colors):
    box.set_facecolor(color)

# 设置其他绘图属性
plt.title('Performance Metrics Comparison')
plt.ylabel('Score')
plt.grid(False)
# 去掉右侧和上边的框线
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)
# plt.ylim(0)
plt.show()
